# %%
a = 3 
b = 10
print a+b
# Out:
# 13

# %%
w = raw_input("hello, whats the weather?")
if w == "sunny":
    print("Its good day")
else:
    print("Today is {} day".format(w))
# Out:
# hello, whats the weather?rainy
# Today is rainy day

# %%
import requests
res = requests.get('https://www.ptt.cc/bbs/Food/index.html')
print res.text
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Food 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/bbs.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/bbs-print.css" media="print">
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.14/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
# ...

# %%
from bs4 import BeautifulSoup 
soup = BeautifulSoup(res.text)
for head in soup.select('.r-ent a'):
    print head.text
# Out:
# [食記][台南市] 丸龜製麵 台南新光三越中山店
# [食記] 阿星鹹粥 台南人才知道的道地早餐
# [食記] 香港 佳佳甜品 日夜思念的米其林港式甜湯
# [食記] 台南 必吃優質燒肉 碳佐麻里
# [食記] 台北喜來登請客樓 適合長輩的舒心美食
# [食記] 高雄 鹽埕區婆婆冰
# [廣宣] 桃園平鎮 老么的店 專業牛肉麵
# [食記] 台北麟光 比臉還大的雞排便當-池上便當
# [食記] 台中-靜岡勝政日式豬排-中友店
# [公告] Food板 板規 V3.8
# 精華區使用方法  【重要！新手必看！】
# [公告] 發文請在標題加上地區及提供地址電話。^^
# [公告] 文章被刪除者請洽精華區的資源回收桶
# [公告] 板規16發文標題須含餐廳店名之調整

# %%
import sys
help(sys.ps3)
# Out:
# no Python documentation found for 'Out:'

# %%
s = 'hellohjkjkghghjg'
#從一開始出發 到八 x += 2
print s[1:8:2]
# Out:
# elhk

# %%
s = """【辛啟松、楊   適群╱台南報導】台南市政府太大意   了！台南地方  法院上周五凌晨即裁定假扣押維冠大樓建商林明輝、
    建築師   張魁寶、鄭進貴   的財產，   但台南市府竟沒在第一時間完成假扣押的行   政程序，在農曆春節出現3天空窗期，
    昨上午  差點被鄭   進貴的妻子領走一千多萬元存款，成功脫產      ，幸好銀   行主管機警，憑著拖延戰術不讓鄭妻領款，
    保住災民  千萬賠償金      ，過程讓人捏把冷汗。台南市府法制處長蕭     博仁坦承確有疏失，表示「同仁敏感度不夠」。'
    """
print s

#分開在組合
print ''.join(s.split())
# Out:
# 【辛啟松、楊   適群╱台南報導】台南市政府太大意   了！台南地方  法院上周五凌晨即裁定假扣押維冠大樓建商林明輝、
#     建築師   張魁寶、鄭進貴   的財產，   但台南市府竟沒在第一時間完成假扣押的行   政程序，在農曆春節出現3天空窗期，
#     昨上午  差點被鄭   進貴的妻子領走一千多萬元存款，成功脫產      ，幸好銀   行主管機警，憑著拖延戰術不讓鄭妻領款，
#     保住災民  千萬賠償金      ，過程讓人捏把冷汗。台南市府法制處長蕭     博仁坦承確有疏失，表示「同仁敏感度不夠」。'
#
# 【辛啟松、楊適群╱台南報導】台南市政府太大意了！台南地方法院上周五凌晨即裁定假扣押維冠大樓建商林明輝、建築師張魁寶、鄭進貴的財產，但台南市府竟沒在第一時間完成假扣押的行政程序，在農曆春節出現3天空窗期，昨上午差點被鄭進貴的妻子領走一千多萬元存款，成功脫產，幸好銀行主管機警，憑著拖延戰術不讓鄭妻領款，保住災民千萬賠償金，過程讓人捏把冷汗。台南市府法制處長蕭博仁坦承確有疏失，表示「同仁敏感度不夠」。'

# %%
dic3 = {'a':1, 'b':3, 'c':3}
print dic3

print dic.keys()

print dic.values()

print dic['a']

print dic.get('a')
# Out:
# {'a': 1, 'c': 3, 'b': 3}
# ['a', 'c', 'b']
# [1, 3, 2]
# 1
# 1
